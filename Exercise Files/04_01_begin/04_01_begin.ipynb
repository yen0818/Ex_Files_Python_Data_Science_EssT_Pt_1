# %% [markdown]
# # Chapter 4 - Practical Data Visualization
# ## Segment 1 - Creating standard data graphics

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Creating a line chart from a list object

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %%
x = range(1, 10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(y)

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
cars = pd.read_csv('C:/Users/yenhongc/Ex_Files_Python_Data_Science_EssT_Pt_1/Exercise Files/Data/mtcars.csv')
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars['mpg']

# %%
mpg.plot()
# Out:
# <AxesSubplot:>

# %%
df = cars[['cyl','wt','mpg']]
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
mpg.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
mpg.plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ### Saving a plot

# %%
plt.pie
